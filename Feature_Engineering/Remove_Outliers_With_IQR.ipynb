# %% [markdown]
# <a href="https://colab.research.google.com/github/RifatMuhtasim/Data_Science/blob/main/Feature_Engineering/Remove_Outliers_With_IQR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/ML/FeatureEngineering/3_outlier_IQR/Exercise/height_weight.csv")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (10000, 3)
#   gender     height      weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.describe()
# Out:
#              height        weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %% [markdown]
# ### Height Outliers

# %%
Q1 = df['height'].quantile(0.25)
Q3 = df['height'].quantile(0.75)

IQR = Q3 - Q1
IQR
# Out:
# 5.668641245615746

# %%
height_lower_limit = Q1 - 1.5*IQR
height_upper_limit = Q3 + 1.5*IQR
height_lower_limit, height_upper_limit
# Out:
# (55.00265861279534, 77.67722359525831)

# %%
df[ (df['height'] > height_lower_limit) &  (df['height'] < height_upper_limit) ]
# Out:
#       gender     height      weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [9992 rows x 3 columns]

# %% [markdown]
# # Weight Outliers

# %%
Q1 = df['weight'].quantile(0.25)
Q3 = df['weight'].quantile(0.75)

IQR = Q3 - Q1
IQR
# Out:
# 51.35147356318197

# %%
weight_lower_limit = Q1 - 1.5*IQR
weight_upper_limit = Q3 + 1.5*IQR
weight_lower_limit, weight_upper_limit
# Out:
# (58.79084096072856, 264.19673521345646)

# %%
df[ (df['weight'] > weight_lower_limit) &  (df['weight'] < weight_upper_limit) ]
# Out:
#       gender     height      weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [9999 rows x 3 columns]
